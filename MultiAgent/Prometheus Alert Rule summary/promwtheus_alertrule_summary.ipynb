# %%
# from langchain.agents import initialize_agent, Tool
from langchain_core.tools import tool
from langgraph.graph import StateGraph, END
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
# from langchain.chat_models import ChatOpenAI
from langchain_openai import ChatOpenAI
from typing import Optional, TypedDict, Annotated
from pydantic.v1 import BaseModel, Field
import operator
# from langchain.prompts import PromptTemplate
import requests
from github import Github
import os
import getpass
from bandit.core import manager, config
from azure.identity import ManagedIdentityCredential
import config
import pandas as pd
import ollama
import tempfile
from langchain_ollama import ChatOllama
from langgraph.prebuilt import create_react_agent

# %%
# model_to_use = "llama3.3:latest"
llm = ChatOllama(model="llama3.3:latest", temperature=0.1)

# %%
def get_prometheus_rule_groups(subscription_id=config.SUBSCRIPTION, resource_group=config.RESOURCEGROUP, client_id=config.PROMETHEUS_CLIENT_ID):
    """
    Fetch Prometheus rule groups from Azure Monitor and return as a DataFrame.

    # Args:
    #     subscription_id (str): Azure subscription ID.
    #     resource_group (str): Azure resource group name.
    #     api_version (str): API version to use.
    #     client_id (str): Client ID for Managed Identity.

    Returns:
        pd.DataFrame: DataFrame containing rule group details, or None if the request fails.
    """
    # Get token using Managed Identity (DefaultAzureCredential)
    credential = ManagedIdentityCredential(client_id=client_id)
    token = credential.get_token("https://management.azure.com/.default").token

    # Construct API URL for listing all rule groups
    url = (
        f"https://management.azure.com/subscriptions/{subscription_id}"
        f"/resourceGroups/{resource_group}/providers/Microsoft.AlertsManagement"
        f"/prometheusRuleGroups?api-version=2023-03-01"
    )

    # Set headers with the bearer token
    headers = {
        "Authorization": f"Bearer {token}",
        "Content-Type": "application/json"
    }

    # Make the GET request to Azure Monitor
    response = requests.get(url, headers=headers)

    # Check and process response
    if response.status_code == 200:
        data = response.json()
        rule_groups = []
        for rule_group in data.get("value", []):
            rule_groups.append({
                "Name": rule_group['name'],
                "Location": rule_group.get('location'),
                "Description": rule_group.get('properties', {}).get('description'),
                "Rules": rule_group.get('properties', {}).get('rules')
            })
        return pd.DataFrame(rule_groups)
    else:
        print(f"Failed to fetch rule groups. Status Code: {response.status_code}")
        print(response.text)
        return None

# %%
alert_rules_df =  get_prometheus_rule_groups()

df_exploded = alert_rules_df.explode('Rules', ignore_index=True)
df_normalized = pd.concat(
    [df_exploded.drop(['Rules'], axis=1), df_exploded['Rules'].apply(pd.Series)],
    axis=1
)
df_normalized
# Out:
#                                              Name Location  \
# 0    NodeRecordingRulesRuleGroup-eastus-stage-arc   eastus
# 1    NodeRecordingRulesRuleGroup-eastus-stage-arc   eastus
# 2    NodeRecordingRulesRuleGroup-eastus-stage-arc   eastus
# 3    NodeRecordingRulesRuleGroup-eastus-stage-arc   eastus
# 4    NodeRecordingRulesRuleGroup-eastus-stage-arc   eastus
# ..                                            ...      ...
# 473                                   RPRuleGroup   eastus
# 474                                   RPRuleGroup   eastus
# 475                                   RPRuleGroup   eastus
# 476                            ONTAPRuleGroup-SRE   eastus
# 477                               ONTAP2RuleGroup   eastus
#
#                               Description  \
# 0    Node Recording Rules RuleGroup - 0.1
# 1    Node Recording Rules RuleGroup - 0.1
# 2    Node Recording Rules RuleGroup - 0.1
# 3    Node Recording Rules RuleGroup - 0.1
# 4    Node Recording Rules RuleGroup - 0.1
# ..                                    ...
# 473              Resource Provider alerts
# 474              Resource Provider alerts
# 475              Resource Provider alerts
# 476                          ONTAP alerts
# 477                          ONTAP alerts
#
#                                      record  \
# 0                 instance:node_num_cpu:sum
# 1      instance:node_cpu_utilisation:rate5m
# 2         instance:node_load1_per_cpu:ratio
# 3    instance:node_memory_utilisation:ratio
# 4    instance:node_vmstat_pgmajfault:rate5m
# ..                                      ...
# 473                                     NaN
# 474                                     NaN
# 475                                     NaN
# 476                                     NaN
# 477                                     NaN
#
#                                             expression  \
# 0    count without (cpu, mode) (  node_cpu_seconds_...
# 1    1 - avg without (cpu) (  sum without (mode) (r...
# 2    (  node_load1{job="node"}/  instance:node_num_...
# 3    1 - (  (    node_memory_MemAvailable_bytes{job...
# 4         rate(node_vmstat_pgmajfault{job="node"}[5m])
# ..                                                 ...
# 473  increase(rp_faulttolerance_job_processed_count...
# 474                     increase(rp_tor_down[10m]) > 0
# 475  rate(rp_external_rp_request_reponses_bucket{le...
# 476  (count(node_failed_power > 0) by (ontap_cluste...
# 477  (count(node_failed_power > 0) by (ontap_cluste...
#
#                                                 labels  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 473  {'metric': 'rp_faulttolerance_job_processed_co...
# 474     {'metric': 'rp_tor_down', 'service': 'anf-rp'}
# 475  {'metric': 'rp_external_rp_request_reponses_bu...
# 476  {'metric': 'node_failed_power', 'service': 'On...
# 477  {'metric': 'node_failed_power', 'service': 'On...
#
#                             alert enabled  severity    for  \
# 0                             NaN     NaN       NaN    NaN
# 1                             NaN     NaN       NaN    NaN
# 2                             NaN     NaN       NaN    NaN
# 3                             NaN     NaN       NaN    NaN
# 4                             NaN     NaN       NaN    NaN
# ..                            ...     ...       ...    ...
# 473  RPUnableToCommunicateWithCVS    True       4.0    NaN
# 474                     RPTORDown    True       4.0    NaN
# 475  RPUnableToCommunicateWithCVS    True       4.0    NaN
# 476               OntapPSUFailure    True       4.0  PT10M
# 477               OntapPSUFailure    True       4.0  PT10M
#
#                                                actions  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 473  [{'actionGroupId': '/subscriptions/2f495c46-73...
# 474  [{'actionGroupId': '/subscriptions/2f495c46-73...
# 475  [{'actionGroupId': '/subscriptions/2f495c46-73...
# 476  [{'actionGroupId': '/subscriptions/2f495c46-73...
# 477  [{'actionGroupId': '/subscriptions/2f495c46-73...
#
#                                  resolveConfiguration  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 473  {'autoResolved': True, 'timeToResolve': 'PT10M'}
# 474  {'autoResolved': True, 'timeToResolve': 'PT10M'}
# 475  {'autoResolved': True, 'timeToResolve': 'PT10M'}
# 476   {'autoResolved': True, 'timeToResolve': 'PT1M'}
# 477   {'autoResolved': True, 'timeToResolve': 'PT1M'}
#
#                                            annotations
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 473  {'description': 'RP pod #$.labels.pod# is repo...
# 474  {'description': 'RP pod #$.labels.pod# is repo...
# 475  {'description': 'RP pod #$.labels.pod# is unab...
# 476  {'description': 'Ontap:Multiple nodes with PSU...
# 477  {'description': 'Ontap:Multiple nodes with PSU...
#
# [478 rows x 13 columns]

# %%
# from langchain_core.messages import AIMessage

# messages = [
#     (
#         "system",
#         "You are a helpful assistant that translates prometheus alert rules to understandabale english. Translate the user question.",
#     ),
#     ("human", f"Translate the alert rule definitions in {df_normalized}, do it for all the rules in the rules column, add the results to a new column to the dataframe"),
# ]
# ai_msg = llm.invoke(messages)
# ai_msg

def translate_rule(row):
    messages = [
        (
            "system",
            "You are a helpful assistant that translates prometheus alert rules to understandable english. Translate the user question.",
        ),
        ("human", f"Translate the following Prometheus rule:\nRecord: {row['record']}\nExpression: {row['expression']}\nReturn only the translation."),
    ]
    ai_msg = llm.invoke(messages)
    return ai_msg.content if hasattr(ai_msg, "content") else str(ai_msg)

df_normalized['translation'] = df_normalized.apply(translate_rule, axis=1)
df_normalized
# Out:
#                                              Name Location  \
# 0    NodeRecordingRulesRuleGroup-eastus-stage-arc   eastus
# 1    NodeRecordingRulesRuleGroup-eastus-stage-arc   eastus
# 2    NodeRecordingRulesRuleGroup-eastus-stage-arc   eastus
# 3    NodeRecordingRulesRuleGroup-eastus-stage-arc   eastus
# 4    NodeRecordingRulesRuleGroup-eastus-stage-arc   eastus
# ..                                            ...      ...
# 473                                   RPRuleGroup   eastus
# 474                                   RPRuleGroup   eastus
# 475                                   RPRuleGroup   eastus
# 476                            ONTAPRuleGroup-SRE   eastus
# 477                               ONTAP2RuleGroup   eastus
#
#                               Description  \
# 0    Node Recording Rules RuleGroup - 0.1
# 1    Node Recording Rules RuleGroup - 0.1
# 2    Node Recording Rules RuleGroup - 0.1
# 3    Node Recording Rules RuleGroup - 0.1
# 4    Node Recording Rules RuleGroup - 0.1
# ..                                    ...
# 473              Resource Provider alerts
# 474              Resource Provider alerts
# 475              Resource Provider alerts
# 476                          ONTAP alerts
# 477                          ONTAP alerts
#
#                                      record  \
# 0                 instance:node_num_cpu:sum
# 1      instance:node_cpu_utilisation:rate5m
# 2         instance:node_load1_per_cpu:ratio
# 3    instance:node_memory_utilisation:ratio
# 4    instance:node_vmstat_pgmajfault:rate5m
# ..                                      ...
# 473                                     NaN
# 474                                     NaN
# 475                                     NaN
# 476                                     NaN
# 477                                     NaN
#
#                                             expression  \
# 0    count without (cpu, mode) (  node_cpu_seconds_...
# 1    1 - avg without (cpu) (  sum without (mode) (r...
# 2    (  node_load1{job="node"}/  instance:node_num_...
# 3    1 - (  (    node_memory_MemAvailable_bytes{job...
# 4         rate(node_vmstat_pgmajfault{job="node"}[5m])
# ..                                                 ...
# 473  increase(rp_faulttolerance_job_processed_count...
# 474                     increase(rp_tor_down[10m]) > 0
# 475  rate(rp_external_rp_request_reponses_bucket{le...
# 476  (count(node_failed_power > 0) by (ontap_cluste...
# 477  (count(node_failed_power > 0) by (ontap_cluste...
#
#                                                 labels  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 473  {'metric': 'rp_faulttolerance_job_processed_co...
# 474     {'metric': 'rp_tor_down', 'service': 'anf-rp'}
# 475  {'metric': 'rp_external_rp_request_reponses_bu...
# 476  {'metric': 'node_failed_power', 'service': 'On...
# 477  {'metric': 'node_failed_power', 'service': 'On...
#
#                             alert enabled  severity    for  \
# 0                             NaN     NaN       NaN    NaN
# 1                             NaN     NaN       NaN    NaN
# 2                             NaN     NaN       NaN    NaN
# 3                             NaN     NaN       NaN    NaN
# 4                             NaN     NaN       NaN    NaN
# ..                            ...     ...       ...    ...
# 473  RPUnableToCommunicateWithCVS    True       4.0    NaN
# 474                     RPTORDown    True       4.0    NaN
# 475  RPUnableToCommunicateWithCVS    True       4.0    NaN
# 476               OntapPSUFailure    True       4.0  PT10M
# 477               OntapPSUFailure    True       4.0  PT10M
#
#                                                actions  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 473  [{'actionGroupId': '/subscriptions/2f495c46-73...
# 474  [{'actionGroupId': '/subscriptions/2f495c46-73...
# 475  [{'actionGroupId': '/subscriptions/2f495c46-73...
# 476  [{'actionGroupId': '/subscriptions/2f495c46-73...
# 477  [{'actionGroupId': '/subscriptions/2f495c46-73...
#
#                                  resolveConfiguration  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 473  {'autoResolved': True, 'timeToResolve': 'PT10M'}
# 474  {'autoResolved': True, 'timeToResolve': 'PT10M'}
# 475  {'autoResolved': True, 'timeToResolve': 'PT10M'}
# 476   {'autoResolved': True, 'timeToResolve': 'PT1M'}
# 477   {'autoResolved': True, 'timeToResolve': 'PT1M'}
#
#                                            annotations  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 473  {'description': 'RP pod #$.labels.pod# is repo...
# 474  {'description': 'RP pod #$.labels.pod# is repo...
# 475  {'description': 'RP pod #$.labels.pod# is unab...
# 476  {'description': 'Ontap:Multiple nodes with PSU...
# 477  {'description': 'Ontap:Multiple nodes with PSU...
#
#                                            translation
# 0    Count the total number of nodes that are repor...
# 1    The average CPU utilization across all CPUs fo...
# 2    "The average load on a single CPU for each ins...
# 3    This rule calculates the ratio of used memory ...
# 4    "The rate of major page faults per second for ...
# ..                                                 ...
# 473  There has been an increase in the number of fa...
# 474  There has been an increase in the number of ti...
# 475  The average rate of external RP requests that ...
# 476  Alert when more than 2 nodes in the same ONTAP...
# 477  Alert when more than 2 nodes in the same ONTAP...
#
# [478 rows x 14 columns]

# %%
df_normalized.to_csv('prom-alerts-def.csv', index = False, encoding = 'UTF-8', header = True)

# %%
ai_msg.content
# Out:
# 'To translate the alert rule definitions into understandable English and add the results to a new column in the DataFrame, we\'ll need to iterate over each rule in the `Rules` column, parse its components (such as `record`, `alert`, `expr`, etc.), and then generate a human-readable description based on those components.\n\nGiven the complexity of Prometheus alert rules, which can include various metrics, operators, and functions, providing an exact translation for every possible rule is challenging without specific examples. However, we can create a basic function to handle common cases and provide a framework that you can extend as needed.\n\nBelow is a simplified Python example using pandas to process the DataFrame. This script includes a basic function `translate_rule` that attempts to parse and translate rules into human-readable text. Note that this is a simplified approach and might need adjustments based on the actual complexity of your rules.\n\n```python\nimport pandas as pd\n\n# Assuming df is your DataFrame with \'Rules\' column containing alert rule definitions\ndef translate_rule(rule):\n    if isinstance(rule, list):  # If rule is a list (common for recording rules)\n        translations = []\n        for r in rule:\n            if \'record\' in r:  # Recording rule\n                translation = f"Record {r[\'record\']} with expression {r.get(\'expr\', \'\')}"\n            elif \'alert\' in r:  # Alerting rule\n                translation = f"Alert {r[\'alert\']} is {\'\' if r.get(\'enabled\', False) else \'not \'}enabled"\n            else:\n                translation = "Unknown rule type"\n            translations.append(translation)\n        return "; ".join(translations)\n    elif isinstance(rule, dict):  # If rule is a single dictionary\n        if \'record\' in rule:  \n            return f"Record {rule[\'record\']} with expression {rule.get(\'expr\', \'\')}"\n        elif \'alert\' in rule:\n            return f"Alert {rule[\'alert\']} is {\'\' if rule.get(\'enabled\', False) else \'not \'}enabled"\n        else:\n            return "Unknown rule type"\n    else:\n        return "Rule format not recognized"\n\n# Apply the translation function to each row in the \'Rules\' column\ndf[\'Translated_Rules\'] = df[\'Rules\'].apply(translate_rule)\n\nprint(df)\n```\n\nThis script defines a `translate_rule` function that attempts to parse and translate rules. It checks if the rule is a list (common for recording rules) or a dictionary, and then tries to extract meaningful information like the record name or alert name along with its status.\n\nPlease note:\n- The actual implementation might need adjustments based on the specifics of your Prometheus alert rules.\n- This example does not handle all possible complexities of Prometheus query language (PromQL).\n- For more accurate translations, consider integrating a PromQL parser library if available.'
